# %%
import warnings
warnings.simplefilter('ignore')

# %%
import warnings

# %%
import pandas as p

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a=p.read_csv("C:\\Users\\admin\\Downloads\\Admission_Predict.csv")

# %%
p=a.drop(["Serial No.","GRE Score","TOEFL Score","University Rating","SOP","LOR ","Research"],axis=1)

# %%
p
# Out:
#      CGPA  Chance of Admit
# 0    9.65              0.92
# 1    8.87              0.76
# 2    8.00              0.72
# 3    8.67              0.80
# 4    8.21              0.65
# ..    ...               ...
# 395  9.04              0.82
# 396  9.11              0.84
# 397  9.45              0.91
# 398  8.78              0.67
# 399  9.66              0.95
#
# [400 rows x 2 columns]

# %%
x=p.iloc[:,0].values.reshape(-1,1)
y=p.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[9.65],
#        [8.87],
#        [8.  ],
#        [8.67],
#        [8.21],
#        [9.34],
#        [8.2 ],
#        [7.9 ],
#        [8.  ],
#        [8.6 ],
#        [8.4 ],
#        [9.  ],
#        [9.1 ],
#        [8.  ],
#        [8.2 ],
#        [8.3 ],
#        [8.7 ],
#        [8.  ],
#        [8.8 ],
#        [8.5 ],
#        [7.9 ],
#        [8.4 ],
#        [9.5 ],
#        [9.7 ],
#        [9.8 ],
#        [9.6 ],
#        [8.8 ],
#        [7.5 ],
#        [7.2 ],
#        [7.3 ],
#        [8.1 ],
#        [8.3 ],
#        [9.4 ],
#        [9.6 ],
#        [9.8 ],
#        [9.2 ],
#        [8.4 ],
#        [7.8 ],
#        [7.5 ],
#        [7.7 ],
#        [8.  ],
#        [8.2 ],
#        [8.5 ],
#        [9.1 ],
#        [9.4 ],
#        [9.1 ],
#        [9.3 ],
#        [9.7 ],
#        [8.85],
#        [8.4 ],
#        [8.3 ],
#        [7.9 ],
#        [8.  ],
#        [8.1 ],
#        [8.  ],
#        [7.7 ],
#        [7.4 ],
#        [7.6 ],
# ...

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
plt.scatter(x,y)
plt.xlabel("GRE Score")
plt.ylabel("Chance of Admit")
plt.title('linear reg')
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
l
# Out:
# LinearRegression()

# %%
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=l.predict(x_test)

# %%
c=p.DataFrame(x_test,columns=['CGPA'])

# %%
c
# Out:
#      CGPA
# 0    8.56
# 1    8.60
# 2    8.76
# 3    8.26
# 4    8.73
# ..    ...
# 115  9.26
# 116  9.34
# 117  8.40
# 118  8.37
# 119  8.13
#
# [120 rows x 1 columns]

# %%
c['AVLDATA']=y_test

# %%
c
# Out:
#      CGPA  AVLDATA
# 0    8.56     0.71
# 1    8.60     0.70
# 2    8.76     0.79
# 3    8.26     0.73
# 4    8.73     0.72
# ..    ...      ...
# 115  9.26     0.91
# 116  9.34     0.90
# 117  8.40     0.78
# 118  8.37     0.70
# 119  8.13     0.59
#
# [120 rows x 2 columns]

# %%
c['PRDDATA']=y_predict

# %%
c
# Out:
#      CGPA  AVLDATA   PRDDATA
# 0    8.56     0.71  0.715085
# 1    8.60     0.70  0.723514
# 2    8.76     0.79  0.757233
# 3    8.26     0.73  0.651862
# 4    8.73     0.72  0.750911
# ..    ...      ...       ...
# 115  9.26     0.91  0.862604
# 116  9.34     0.90  0.879464
# 117  8.40     0.78  0.681366
# 118  8.37     0.70  0.675044
# 119  8.13     0.59  0.624466
#
# [120 rows x 3 columns]

# %%
plt.scatter(x,y,color='red')
plt.plot(x_test,y_predict,color='blue')
plt.xlabel('CGPA')
plt.ylabel('CHA')
plt.title('linear reg')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.005574931139058404
